# %%
from modelzipper.tutils import *
import matplotlib.pyplot as plt
import numpy as np
import os
from pprint import pprint
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# nltk.download('punkt')
# nltk.download('stopwords')

# 英文停用词
stop_words = set(stopwords.words('english'))

# file_dir = "/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/1900/ce"
 
# file_dir = "/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal/Meta-Llama-3.1-8B-Instruct/1900/ce"

file_dir = "/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/1900/ce"
prefix = "3-hop*"
all_files = auto_read_dir(file_dir, file_prefix=prefix)
i = 0
all_files = [os.path.join(file_dir, x) for x in all_files]
len(all_files)
# Out:
# 2025-01-18 17:37:53.685 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 210

# %%
for i in range(2):
    single_data = pickle.load(open(all_files[i],"rb"))
    print(single_data['pred_res'],single_data['score'])
# Out:
# the office<|eot_id|> 0
# the bedroom<|eot_id|> 100

# %%
for i in range(10):
    single_data = pickle.load(open(all_files[i],"rb"))
    print(single_data['pred_res'],single_data['score'])
# Out:
# There is no information about a football before the bathroom in the text.<|eot_id|> 0
# There is no information about a football in the given text before the bathroom.<|eot_id|> 0
# There is no information about a football in the bathroom before the bathroom. The text only mentions Mary journeyed to the office, then Mary journeyed to the bathroom 100
# There is no information about the football before the bathroom. The text only mentions that Mary got the football there.<|eot_id|> 0
# There is no information about a football in the given text before the bathroom.<|eot_id|> 0
# There is no information about a football in the given text before the bathroom.<|eot_id|> 0
# There is no information about a football before the bathroom in the text.<|eot_id|> 0
# There is no information about a football in the bathroom before the bathroom. The text only mentions Mary journeyed to the bathroom and then Sandra journeyed to the bathroom 0
# ...

# %%
for i in range(5):
    single_data = pickle.load(open(all_files[i],"rb"))
    print(single_data['pred_res'],single_data['score'])
# Out:
# the office<|eot_id|> 100
# the office<|eot_id|> 100
# the office<|eot_id|> 100
# the office<|eot_id|> 100
# the office<|eot_id|> 100

# %%
for i in range(5):
    single_data = pickle.load(open(all_files[i],"rb"))
    print(single_data['pred_res'],single_data['score'])
# Out:
# the office<|eot_id|> 100
# the office<|eot_id|> 100
# the garden<|eot_id|> 0
# the bedroom<|eot_id|> 0
# the office<|eot_id|> 100

# %%
single_data = pickle.load(open(all_files[0],"rb"))
single_data
# Out:
# {28: {'score': [5.563100179036459e-07,
#    7.745870322729981e-08,
#    1.9486133868877704e-07,
#    7.355125725706516e-08],
#   'topk_tokens': [' before',
#    ' bathroom',
#    ' ST',
#    ' got',
#    ' football',
#    'Mary',
#    ' the',
#    'Answer',
#    ' football',
#    ' a',
#    'office',
#    ' the',
#    ' the',
#    ' got',
#    '<|start_header_id|>',
#    'Bridge',
#    '<|end_header_id|>',
#    '<|begin_of_text|>',
#    'assistant',
#    ':'],
#   'evidence_proportions': [1.532690865652902e-07,
#    1.6093254089355469e-06,
#    4.002026149204799e-07,
#    2.1287373134068081e-07]},
#  29: {'score': [1.7439877545392072e-07,
#    4.7936924062660285e-08,
#    1.2837923490084134e-07,
#    4.6590721111717317e-08],
#   'topk_tokens': ['RE',
#    ' Paul',
#    ' were',
#    ' the',
#    '\n\n',
#    ' Do',
#    ' the',
#    ' the',
#    ' the',
#    '?\n',
#    ' of',
#    'Answer',
#    '\n',
#    '<|end_header_id|>',
#    ' before',
#    'assistant',
# ...

# %%
single_data = pickle.load(open(all_files[0],"rb"))
single_data
# Out:
# {28: {'score': [1.0154865406177663e-06,
#    9.617597159630372e-08,
#    4.6537472651554987e-07,
#    8.776018846880253e-08],
#   'topk_tokens': [' garden',
#    ' Mary',
#    ' to',
#    ' Where',
#    ' the',
#    ' back',
#    ' football',
#    ' the',
#    'office',
#    ' got',
#    ':',
#    ' the',
#    'Answer',
#    ' football',
#    ' got',
#    'Bridge',
#    '<|end_header_id|>',
#    '<|start_header_id|>',
#    'assistant',
#    '<|begin_of_text|>'],
#   'evidence_proportions': [3.491129193987165e-07,
#    2.3146470387776694e-06,
#    5.108969552176339e-07,
#    1.0728836059570312e-06]},
#  29: {'score': [2.472488968460648e-07,
#    5.0569714309799194e-08,
#    1.8798387967623197e-07,
#    4.839780569659468e-08],
#   'topk_tokens': [' the',
#    ' the',
#    ',',
#    '\n\n',
#    ' Do',
#    ' Where',
#    ' the',
#    ' Paul',
#    '\n',
#    '.\n\n',
#    'ot',
#    '?\n',
#    'Answer',
#    '<|end_header_id|>',
#    ' before',
#    'assistant',
#    'office',
# ...

# %%
single_data = pickle.load(open(all_files[0],"rb"))
single_data
# Out:
# {28: {'score': [1.0592627438233681e-06,
#    1.4253617270852253e-07,
#    1.0770059956345135e-06,
#    1.1905707609953422e-07],
#   'topk_tokens': [' to',
#    'Mary',
#    ' the',
#    ' to',
#    ' ',
#    ' of',
#    ' the',
#    ' ST',
#    ' before',
#    ' the',
#    ' the',
#    ' office',
#    ' a',
#    '<|end_header_id|>',
#    ' office',
#    ' the',
#    '<|start_header_id|>',
#    '<|begin_of_text|>',
#    'assistant',
#    ':'],
#   'evidence_proportions': [1.4636898413300514e-06,
#    4.400462785270065e-07,
#    1.7753378155508211e-06,
#    4.695175448432565e-07]},
#  29: {'score': [3.9101622759416284e-07,
#    8.181903333456215e-08,
#    3.081826994625422e-07,
#    7.500535235594238e-08],
#   'topk_tokens': ['Mary',
#    ' the',
#    ' the',
#    ' PA',
#    '<|eot_id|>',
#    'RE',
#    '?\n',
#    ' were',
#    ' a',
#    '***',
#    '.',
#    '<|end_header_id|>',
#    ' the',
#    ' of',
#    '<|begin_of_text|>',
#    'ot',
#    ' before',
#    'assistant',
# ...

# %%
single_data = pickle.load(open(all_files[1],"rb"))
single_data
# Out:
# {26: {'score': [2.0383296301857895e-07,
#    3.462930120241806e-08,
#    1.0500758137893101e-06,
#    2.7057147609191766e-08],
#   'topk_tokens': [' was',
#    ' a',
#    ' office',
#    'Mary',
#    ' the',
#    '.',
#    ' the',
#    ' Bench',
#    ' office',
#    '?\n',
#    ' the',
#    ' Where',
#    '\n\n',
#    'Bridge',
#    '***',
#    ' the',
#    '<|start_header_id|>',
#    ' bedroom',
#    ' bedroom',
#    ':'],
#   'evidence_proportions': [2.9137091977255683e-07,
#    2.2630532233354947e-07,
#    2.0674789474079652e-07,
#    9.41180522724088e-08]},
#  27: {'score': [2.195724610592825e-06,
#    7.499514090091947e-08,
#    2.0843456066079225e-06,
#    4.822183826276213e-08],
#   'topk_tokens': [' the',
#    ' the',
#    ' football',
#    ' Paul',
#    ' the',
#    'Mary',
#    ' the',
#    ' office',
#    'Bridge',
#    ' the',
#    ' the',
#    ' the',
#    ' the',
#    '<|end_header_id|>',
#    ' the',
#    '<|start_header_id|>',
#    '<|begin_of_text|>',
# ...

# %%
from collections import defaultdict
from argparse import Namespace

x = list(range(32))
corrects = []
wrongs = []
corrects_irrelevant = []
wrongs_irrelevant = []
corrects_ba = []
wrongs_ba = []

corrects_rir_ratio = []
wrongs_rir_ratio = []
for layer_idx in x:
    dics = defaultdict(lambda : Namespace(
        has_count = 0,
        all_count = 0,
        irrelevant_count = 0,
        has_question_count = 0,
    ))
    for single_data_path in all_files:
        single_data =pickle.load(open( single_data_path, "rb"))
        dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
        dics[single_data['score']].irrelevant_count += \
            int(((" bedroom" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                and (" office" not in single_data[layer_idx]['topk_tokens']))
        dics[single_data['score']].has_question_count += \
            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
        dics[single_data['score']].all_count += 1    

        # dics[single_data['score']].has_count += int(" bedroom" in single_data[layer_idx]['topk_tokens'])
        # dics[single_data['score']].irrelevant_count += \
        #     int(((" office" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
        #         and (" bedroom" not in single_data[layer_idx]['topk_tokens']))
        # dics[single_data['score']].has_question_count += \
        #     int((" bathroom" in single_data[layer_idx]['topk_tokens']))
        # dics[single_data['score']].all_count += 1 

    # print("Layer:",layer_idx)
    # print("c:",dics[100])
    
    # print("w:",dics[0])

    corrects.append(dics[100].has_count#/dics[100].all_count
                    )
    wrongs.append(dics[0].has_count#/dics[0].all_count
                  )
    
    corrects_irrelevant.append(dics[100].irrelevant_count#/dics[100].all_count
                               )
    wrongs_irrelevant.append(dics[0].irrelevant_count#/dics[0].all_count
                             )

    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
    
    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))



plt.figure(figsize=(10, 6))

# plt.plot(x, corrects,label = "correct")
# plt.plot(x, wrongs, label ="wrong")

# plt.plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
# plt.plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

plt.title("-".join(file_dir.split("/")[-2:]) + "-" + prefix)

plt.plot(x, corrects_rir_ratio,label = "correct_ir/r")
plt.plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

# plt.plot(x, corrects_ba,label = "correct_bathroom_count")
# plt.plot(x, wrongs_ba, label ="wrong_bathroom_count")
# plt.title("answer")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 23
#      21 for single_data_path in all_files:
#      22     single_data =pickle.load(open( single_data_path, "rb"))
# ---> 23     dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
#      24     dics[single_data['score']].irrelevant_count += \
#      25         int(((" bedroom" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
#      26             and (" office" not in single_data[layer_idx]['topk_tokens']))
#      27     dics[single_data['score']].has_question_count += \
#      28         int((" bathroom" in single_data[layer_idx]['topk_tokens']))
#
# KeyError: 0

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop*","4-hop*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" bedroom" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                                and (" office" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count/dics[100].all_count)
                    wrongs.append(dics[0].has_count/dics[0].all_count)
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count/dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count/dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count )/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # plt.plot(x, corrects,label = "correct")
            # plt.plot(x, wrongs, label ="wrong")
            # plt.plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # plt.plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # plt.plot(x, corrects_ba,label = "correct_bathroom_count")
            # plt.plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:53:37.325 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:37.987 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:38.646 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:39.305 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 5
# 2025-01-17 21:53:39.307 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop*' and suffix '': 252
# 2025-01-17 21:53:40.125 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop*' and suffix '': 252
# 2025-01-17 21:53:40.928 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop*' and suffix '': 252
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop*","4-hop*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" bedroom" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" office" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                                and (" bedroom" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:53:45.927 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:46.568 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:47.208 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 112
# 2025-01-17 21:53:47.547 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:48.189 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop*' and suffix '': 210
# 2025-01-17 21:53:48.829 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop*' and suffix '': 252
# 2025-01-17 21:53:49.632 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop*' and suffix '': 252
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-yes*","4-hop-yes*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" bedroom" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                                and (" office" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:54:08.015 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 580
# 2025-01-17 21:54:09.803 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 540
# 2025-01-17 21:54:11.449 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 461
# 2025-01-17 21:54:12.847 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 540
# 2025-01-17 21:54:14.494 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 540
# 2025-01-17 21:54:16.140 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-yes*' and suffix '': 330
# 2025-01-17 21:54:17.139 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-yes*' and suffix '': 714
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-no*","4-hop-no*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" bedroom" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" office" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                                and (" office" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:54:57.677 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:54:57.715 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:54:57.751 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:54:58.103 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:54:58.141 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:54:58.177 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:54:58.529 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-no*' and suffix '': 462
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-no*","4-hop-no*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" bedroom" in single_data[layer_idx]['topk_tokens']) or (" garden" in single_data[layer_idx]['topk_tokens']))\
                                and (" office" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:55:46.417 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:55:46.455 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:55:46.489 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:55:46.837 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:55:46.872 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:55:46.908 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:55:47.265 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-no*' and suffix '': 462
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-no*","4-hop-no*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" garden" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int(((" office" in single_data[layer_idx]['topk_tokens']) or (" bedroom" in single_data[layer_idx]['topk_tokens']))\
                                and (" garden" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:56:42.216 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:56:42.255 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:56:42.292 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:56:42.649 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:56:42.687 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:56:42.723 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:56:43.084 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-no*' and suffix '': 462
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-no*","4-hop-no*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int(" office" in single_data[layer_idx]['topk_tokens'])
                        dics[single_data['score']].irrelevant_count += \
                            int((" football" in single_data[layer_idx]['topk_tokens'])\
                                and (" office" not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 21:41:38.825 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:41:38.862 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:41:38.898 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:41:39.249 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:41:39.287 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 21:41:39.323 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 21:41:39.675 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-no*' and suffix '': 462
# ...

# %%
root_dir ="/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow/Meta-Llama-3.1-8B-Instruct/"

fig,axes = plt.subplots(nrows = 4, ncols = 3,figsize = (20, 15))
row = -1
for hop in ["3-hop-no*","4-hop-no*"]:
    for task in ["ce","label"]:
        row+=1
        for col ,ctx_length in enumerate(["1900","3900","5900"]):
            
            file_dir = os.path.join(root_dir,ctx_length, task)
            if not os.path.exists(file_dir):continue
            all_files = auto_read_dir(file_dir, file_prefix=hop)
            all_files = [os.path.join(file_dir, x) for x in all_files]
            
            x = list(range(32))
            corrects = []
            wrongs = []
            corrects_irrelevant = []
            wrongs_irrelevant = []
            corrects_ba = []
            wrongs_ba = []

            corrects_rir_ratio = []
            wrongs_rir_ratio = []
            try:
                for layer_idx in x:
                    dics = defaultdict(lambda : Namespace(
                        has_count = 0,
                        all_count = 0,
                        irrelevant_count = 0,
                        has_question_count = 0,
                    ))
                    for single_data_path in all_files:
                        
                        ir= " bedroom"
                        r = " office"

                        single_data =pickle.load(open( single_data_path, "rb"))
                        dics[single_data['score']].has_count += int((r in single_data[layer_idx]['topk_tokens']))#\
                                                                    #and(ir not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].irrelevant_count += \
                            int((ir in single_data[layer_idx]['topk_tokens'])\
                                and (r not in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].has_question_count += \
                            int((" bathroom" in single_data[layer_idx]['topk_tokens']))
                        dics[single_data['score']].all_count += 1    

                    # print("Layer:",layer_idx)
                    # print("c:",dics[100])
                    
                    # print("w:",dics[0])

                    corrects.append(dics[100].has_count
                                    # /dics[100].all_count
                                    )
                    wrongs.append(dics[0].has_count
                                #   /dics[0].all_count
                                  )
                    
                    corrects_irrelevant.append(dics[100].irrelevant_count
                                            #    /dics[100].all_count
                                            )
                    wrongs_irrelevant.append(dics[0].irrelevant_count
                                            #  /dics[0].all_count
                                            )

                    corrects_ba.append(dics[100].has_question_count/dics[100].all_count)    
                    wrongs_ba.append(dics[0].has_question_count/dics[0].all_count)

                    corrects_rir_ratio.append((dics[100].irrelevant_count+1)/(dics[100].has_count + 1))
                    
                    wrongs_rir_ratio.append((dics[0].irrelevant_count + 1)/(dics[0].has_count + 1))

            except Exception as e:
                continue
            # plt.figure(figsize=(10, 6))
            # axes[row][col].plot(x, corrects,label = "correct")
            # axes[row][col].plot(x, wrongs, label ="wrong")
            # axes[row][col].plot(x, corrects_irrelevant,label = "correct_irrelevant_count")
            # axes[row][col].plot(x, wrongs_irrelevant, label ="wrong_irrelevant_count")

            axes[row][col].set_title("-".join(file_dir.split("/")[-2:]) + "-" + hop)

            axes[row][col].plot(x, corrects_rir_ratio,label = "correct_ir/r")
            axes[row][col].plot(x, wrongs_rir_ratio, label ="wrong_ir/r")

            # axes[row][col].plot(x, corrects_ba,label = "correct_bathroom_count")
            # axes[row][col].plot(x, wrongs_ba, label ="wrong_bathroom_count")
            # plt.title("answer")
            axes[row][col].legend()
plt.show()
# Out:
# 2025-01-17 22:02:24.195 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 22:02:24.231 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 22:02:24.265 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 22:02:24.624 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 22:02:24.660 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 330
# 2025-01-17 22:02:24.695 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '3-hop-no*' and suffix '': 120
# 2025-01-17 22:02:25.050 | INFO     | modelzipper.tutils:auto_read_dir:371 - number of files with prefix '4-hop-no*' and suffix '': 462
# ...

# %%
single_data = pickle.load(open(all_files[0],"rb"))

# %%
single_data[30]
# Out:
# {'score': [5.50548080354929e-06,
#   1.0390588109293476e-06,
#   1.757252462222382e-06,
#   1.0168684928460413e-06],
#  'topk_tokens': ['<|begin_of_text|>',
#   '.',
#   '<|start_header_id|>',
#   ' location',
#   ' football',
#   ' The',
#   ' Jul',
#   '3',
#   ' only',
#   ' second',
#   ' location',
#   'g',
#   ' respond',
#   "'",
#   ' new',
#   '202',
#   ' with',
#   '4',
#   " '",
#   ' or'],
#  'evidence_proportions': [1.2105863009180342e-06,
#   5.233586610605319e-06,
#   3.584061882325581e-06,
#   1.4534592628479004e-05]}

# %%
tokenizer = AutoTokenizer.from_pretrained("/data/hf_models/Meta-Llama-3.1-8B-Instruct/")

# %%
tokenizer("bedroom")

# %%
single_data[31], single_data['score']

# %%
def plot_layer_data(layer_data, save_path=None, caption=None):
    # 提取数据
    layer_scores, layers = [], []
    for layer_idx, layer in layer_data.items():
        if isinstance(layer, dict):
            layer_scores.append(layer['score'])
            layers.append(layer_idx)
    layer_scores = np.array(layer_scores)

    # 为每个层的四个数值分别定义一个系列
    evidence_weight = layer_scores[:, 0]
    full_context_weight = layer_scores[:, 1]
    attack_context_weight = layer_scores[:, 2]
    remaining_context_weight = layer_scores[:, 3]

    # 创建图形
    plt.figure(figsize=(10, 6))

    # 绘制每层的四个权重
    plt.plot(layers, evidence_weight, label='Evidence Context Weight', color='blue', marker='o')
    plt.plot(layers, full_context_weight, label='Full Context Weight', color='green', marker='x')
    plt.plot(layers, attack_context_weight, label='Attack Context Weight', color='red', marker='s')
    plt.plot(layers, remaining_context_weight, label='Remaining Context Weight', color='purple', marker='^')

    # 添加标题和标签
    if caption is None:
        caption = 'Model Layer Characteristics Across Different Contexts'

    plt.title(caption, fontsize=16)
    plt.xlabel('Layer Number', fontsize=12)
    plt.ylabel('Weight Value', fontsize=12)
    plt.legend()

    # 显示图形
    plt.grid(True)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()

def plot_layer_data_multiple(data_list, save_path=None, captions=None):
    # 创建5x5的子图
    fig, axs = plt.subplots(5, 5, figsize=(20, 20))
    axs = axs.flatten()  # 将子图数组展平，方便迭代

    for i, layer_data in enumerate(data_list):
        if i >= 25:  # 只绘制前25个数据
            break

        # 提取数据
        layer_scores, layers = [], []
        for layer_idx, layer in layer_data.items():
            if isinstance(layer, dict):
                layer_scores.append(layer['score'])
                layers.append(layer_idx)

        layer_scores = np.array(layer_scores)

        # 为每个层的四个数值分别定义一个系列
        evidence_weight = layer_scores[:, 0]
        full_context_weight = layer_scores[:, 1]
        attack_context_weight = layer_scores[:, 2]
        remaining_context_weight = layer_scores[:, 3]

        # 绘制每层的四个权重
        axs[i].plot(layers, evidence_weight, label='Evidence Context Weight', color='blue', marker='o')
        axs[i].plot(layers, full_context_weight, label='Full Context Weight', color='green', marker='x')
        axs[i].plot(layers, attack_context_weight, label='Attack Context Weight', color='red', marker='s')
        axs[i].plot(layers, remaining_context_weight, label='Remaining Context Weight', color='purple', marker='^')

        # 添加标题和标签
        if captions is None:
            captions = ['Model Layer Characteristics'] * 25
        axs[i].set_title(captions[i], fontsize=10)
        axs[i].set_xlabel('Layer Number', fontsize=8)
        axs[i].set_ylabel('Weight Value', fontsize=8)
        axs[i].legend(fontsize=8)
        axs[i].grid(True)

    # 调整布局
    plt.tight_layout()
    
    # 保存或显示图形
    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()

# %%
def count_tokens(content):
    s_lst, d_lst = [], []
    for k, v in content.items():
        if isinstance(k, int):
            if k < 16:
                s_lst.extend(v['topk_tokens'])
            else:
                d_lst.extend(v['topk_tokens'])
            s_lst = list(set(s_lst))
            d_lst = list(set(d_lst))
            # s_lst = [word for word in s_lst if word.lower() not in stop_words and word.isalpha()]
            # d_lst = [word for word in d_lst if word.lower() not in stop_words and word.isalpha()]
    return s_lst, d_lst

# %%
all_predictions = []
labels = []

layers = np.array(list(range(32)))
all_layer_scores = [[0, 0, 0, 0, 0] for i in range(len(layers))]
each_evidence_weight = [[0, 0, 0, 0, 0] for i in range(len(layers))]
file_numbers = 0 
for file in tqdm(all_files):
    settings = os.path.basename(file).split("_")
    hop, depth = settings[0], settings[1]
    label = hop.split("-")[-1].lower()
    content = auto_read_data(file)
    if content['score'] == 0:
        # continue
        all_predictions.append(0)
        
    else:
        continue
        all_predictions.append(1)

    file_numbers +=1
        
    # print(content['pred_res'], content['score'])
    # print(content[0])
    # break
    # 提取数据
    layer_scores = []
    for layer_idx, layer in content.items():
        if isinstance(layer, dict):
            for i, s in enumerate(layer['score']):
                all_layer_scores[layer_idx][i] += s
            for i, s in enumerate(layer['evidence_proportions']):
                each_evidence_weight[layer_idx][i] += s

for layer_idx, scores in enumerate(all_layer_scores):
    for j, score in enumerate(scores):
        scores[j] = scores[j] / file_numbers

for layer_idx, scores in enumerate(each_evidence_weight):
    for j, score in enumerate(scores):
        scores[j] = scores[j] / file_numbers
print("files:",file_numbers)
each_evidence_weight = np.array(each_evidence_weight)
first_evidence_weight = each_evidence_weight[:, 0]
second_evidence_weight = each_evidence_weight[:, 1]
third_evidence_weight = each_evidence_weight[:, 2]
fourth_evidence_weight = each_evidence_weight[:, 3]
fifth_evidence_weight = each_evidence_weight[:, 4]

plt.figure(figsize=(10, 6))

# 绘制每层的四个权重
plt.plot(layers, first_evidence_weight, label='first_evidence_weight', color='blue', marker='o')
plt.plot(layers, second_evidence_weight, label='second_evidence_weight', color='green', marker='x')
plt.plot(layers, third_evidence_weight, label='third_evidence_weight', color='red', marker='s')
plt.plot(layers, fourth_evidence_weight, label='fourth_evidence_weight', color='purple', marker='^')
plt.plot(layers, fifth_evidence_weight, label='fifth_evidence_weight', color='black', marker='*')

plt.title('Layer Score for each Evidence', fontsize=16)
plt.xlabel('Layer Number', fontsize=12)
plt.ylabel('Weight Value', fontsize=12)
plt.legend()

# 显示图形
plt.grid(True)
plt.tight_layout()
plt.show()

all_layer_scores = np.array(all_layer_scores)
# 为每个层的四个数值分别定义一个系列
evidence_weight = all_layer_scores[:, 0]
full_context_weight = all_layer_scores[:, 1]
attack_context_weight = all_layer_scores[:, 2]
remaining_context_weight = all_layer_scores[:, 3]

print(f"accuracy: {np.mean(all_predictions)}")

# 创建图形
plt.figure(figsize=(10, 6))

# 绘制每层的四个权重
plt.plot(layers, evidence_weight, label='Evidence Context Weight', color='blue', marker='o')
plt.plot(layers, full_context_weight, label='Full Context Weight', color='green', marker='x')
plt.plot(layers, attack_context_weight, label='Attack Context Weight', color='red', marker='s')
plt.plot(layers, remaining_context_weight, label='Remaining Context Weight', color='purple', marker='^')

plt.title('Model Layer Characteristics Across Different Contexts', fontsize=16)
plt.xlabel('Layer Number', fontsize=12)
plt.ylabel('Weight Value', fontsize=12)
plt.legend()

# 显示图形
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 210/210 [00:00<00:00, 5809.02it/s]
# begin to read data from /data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/1900/ce/3-hop-bedroom_0-1-4-5.pkl | file size: 11.7 KB | file type: pkl
# begin to read data from /data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/1900/ce/3-hop-bedroom_2-4-5-7.pkl | file size: 11.72 KB | file type: pkl
# begin to read data from /data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/1900/ce/3-hop-bedroom_2-4-5-9.pkl | file size: 11.67 KB | file type: pkl
# begin to read data from /data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/information_flow_normal_simple/Meta-Llama-3.1-8B-Instruct/1900/ce/3-hop-bedroom_0-3-7-8.pkl | file size: 11.71 KB | file type: pkl
# ...

# %%
dir_path = "/data/zecheng/acl2025/MyRLHF/reetrievalheaddetect/analysis/figure/Meta-Llama-3.1-8B-Instruct/5900"
auto_mkdir(dir_path)
succ_cache_lst, fail_cache_lst = [], []
succ_idx, fail_idx = 0, 0
f_shallow_layer_topk_tokens, f_deep_layer_topk_tokens = [], []
s_shallow_layer_topk_tokens, s_deep_layer_topk_tokens = [], []

for file in tqdm(all_files):
    settings = os.path.basename(file).split("_")
    hop, depth = settings[0], settings[1]
    label = hop.split("-")[-1].lower()
    content = auto_read_data(file)

    if label in content["pred_res"].lower():
        succ_cache_lst.append(content)
        # save_path = os.path.join(dir_path, f"correct_{hop}_{depth}.png")
        # s_lst, d_lst = count_tokens(content)
        # s_shallow_layer_topk_tokens.extend(s_lst)
        # s_deep_layer_topk_tokens.extend(d_lst)
        # s_shallow_layer_topk_tokens = list(set(s_shallow_layer_topk_tokens))
        # s_deep_layer_topk_tokens = list(set(s_deep_layer_topk_tokens))
    else:
        fail_cache_lst.append(content)
        # save_path = os.path.join(dir_path, f"wrong_{hop}_{depth}.png")
        # f_s_lst, f_d_lst = count_tokens(content)
        # f_shallow_layer_topk_tokens.extend(f_s_lst)
        # f_deep_layer_topk_tokens.extend(f_d_lst)
        # f_shallow_layer_topk_tokens = list(set(f_shallow_layer_topk_tokens))
        # f_deep_layer_topk_tokens = list(set(f_deep_layer_topk_tokens))
    if len(succ_cache_lst) == 25:
        plot_layer_data_multiple(succ_cache_lst, os.path.join(dir_path, f"correct_{hop}_{succ_idx}.png"))
        succ_cache_lst = []
        succ_idx += 1
    if len(fail_cache_lst) == 25:
        plot_layer_data_multiple(fail_cache_lst, os.path.join(dir_path, f"wrong_{hop}_{fail_idx}.png"))
        fail_cache_lst = []
        fail_idx += 1
    
    if succ_idx > 0 and fail_idx > 0:
        break
    # plot_layer_data(content, save_path, settings)

# %%
pprint(s_shallow_layer_topk_tokens)
pprint(s_deep_layer_topk_tokens)

# %%
pprint(f_shallow_layer_topk_tokens)
pprint(f_deep_layer_topk_tokens)

# %% [markdown]
# 1. 首先按照是否回答正确进行划分

# %%
print(os.path.basename(all_files[0]))
instance = auto_read_data(all_files[0])

print(instance.keys())
topk_tokens = instance[0]['topk_tokens']  # 0 is the layer index
print(topk_tokens)

# %%
instance

# %%
from modelzipper.tutils import *
import matplotlib.pyplot as plt
import numpy as np

# 数据：每层的四个权重数值
layer_data = {
    0: [4.959665238857269e-06, 3.241457776316934e-05, 1.915307207541032e-05, 3.2536576766406514e-05],
    1: [6.113294512033463e-06, 3.588264777170998e-05, 1.875220826177886e-05, 3.602615563138125e-05],
    2: [3.3918768167495728e-06, 3.954556222308137e-05, 1.3849161791078972e-05, 3.973980739152632e-05],
    3: [4.411069676280022e-06, 5.2358093491322196e-05, 8.825382048433477e-06, 5.265427548364616e-05],
    4: [1.409146934747696e-05, 5.386575933844638e-05, 3.642363078666456e-05, 5.403527912603641e-05],
    5: [3.511123359203339e-05, 5.6201644940101574e-05, 3.5292892293496564e-05, 5.633910748514353e-05],
    6: [1.1113425716757775e-05, 7.276903453996061e-05, 2.8178434700803887e-05, 7.310343142066736e-05],
    7: [5.842046812176705e-06, 0.0001060344519507986, 4.455788681904475e-05, 0.0001065330393336028],
    8: [1.1762231588363648e-05, 0.0001127064162164015, 5.673789278124318e-05, 0.00011318438913503663],
    9: [2.7908291667699813e-05, 0.00013008105668458142, 4.593079740350897e-05, 0.00013067705246309438],
    10: [3.418363630771637e-05, 0.0001264135955578132, 5.119948676138213e-05, 0.00012694854421944576],
    11: [1.703500747680664e-05, 0.00011598208717596412, 0.00018443663914998373, 0.00011594746073912442],
    12: [8.40499997138977e-06, 0.00017115683509330904, 6.23587067380096e-05, 0.00017200319697982774],
    13: [0.0006855845451354981, 0.00032301160542711025, 0.0008409402587197044, 0.0003200018249680569],
    14: [0.00020253956317901612, 0.0003778427242573789, 0.0010134717731764822, 0.0003756827718102024],
    15: [6.217481568455696e-05, 0.00031942024437131556, 0.00043356729050477344, 0.0003195906271669796],
    16: [0.013655662536621094, 0.0003536513946724383, 0.001258882609280673, 0.0003170647412450094],
    17: [0.0028010547161102296, 0.00025052682229714346, 0.0014491054144772616, 0.00023932953601892812],
    18: [0.005669236183166504, 0.00029643327858037727, 0.0007366122621478456, 0.0002813514333096739],
    19: [0.0010981798171997071, 0.0001875015840294935, 0.001387981077035268, 0.0001803515607935149],
    20: [0.007794710993766785, 0.0002826679076511171, 0.0023177458029804807, 0.0002557887740868018],
    21: [0.0017806708812713623, 0.00020140549310989484, 0.001226557023597486, 0.0001933175469836189],
    22: [0.001896064169704914, 0.00017294463764580063, 0.0008285483627608328, 0.00016600876801548678],
    23: [0.0013591922819614411, 0.00015825946183714815, 0.0010787226033933234, 0.0001515341972385033],
    24: [0.0015029147267341613, 0.0002128314567774904, 0.001215286637571725, 0.00020555120376496033],
    25: [0.011409810930490493, 0.0002014303863407309, 0.0012002720031887293, 0.0001696389194466929],
    26: [0.0020347237586975098, 0.00016976514241572694, 0.0004434507114417625, 0.00016403680461855895],
    27: [0.002594304084777832, 0.00025047442936777206, 0.0014475617896426809, 0.00023979435073309436],
    28: [0.0008534610271453858, 0.00015710730061251676, 0.0029951467206983857, 0.00014380581997533933],
    29: [0.00024196654558181763, 0.0001313316633156309, 0.0006413843595620358, 0.00012897700992524328],
    30: [0.004878909885883331, 0.00029894708488866395, 0.0019776151713096733, 0.0002807725914574342],
    31: [0.0009814728051424026, 0.0001716352537038241, 0.0005350086386456634, 0.00016815008150651299],
}
