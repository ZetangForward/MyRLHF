# %%
import matplotlib.pyplot as plt

# 数据
api_counts = [400, 300, 200, 100]
avg_lengths = [64310.48, 49141.69, 32543.4875, 16827.855]

# 绘制柱状图
plt.figure(figsize=(10, 6))
plt.bar(api_counts, avg_lengths, color='skyblue', width=40)  # 设置柱子的宽度

# 添加标题和标签
plt.title('Average Length of APIs for Different Query Counts')
plt.xlabel('Number of Queries')
plt.ylabel('Average Length')

# 设置横坐标刻度
plt.xticks(api_counts)  # 只显示四个数字

# 显示数值标签
for i, (api_count, avg_length) in enumerate(zip(api_counts, avg_lengths)):
    plt.text(api_count, avg_length + 1000, f'{avg_length:.2f}', ha='center', va='bottom')

# 显示图形
plt.tight_layout()  # 调整布局以防止标签被截断
plt.show()

# %%
from modelzipper.tutils import *

data = auto_read_data("/mnt/hwfile/opendatalab/tangzecheng/benchmark_data/rapid_multiple_api/tool_location/num_100_pool.json")
# Out:
# 2024-11-18 19:58:01.016 | INFO     | modelzipper.tutils:auto_read_data:182 - begin to read data from /mnt/hwfile/opendatalab/tangzecheng/benchmark_data/rapid_multiple_api/tool_location/num_100_pool.json | file size: 1.1 MB | file type: json

# %%
data
# Out:
# {'0': {'system_prompt': [{'role': 'system',
# ...

# %%
for b_id in data:
    print(b_id)
    print(data[b_id]['source_docs'][0])
# Out:
# 0
# <TOOL_DOC>
# <API_1>
# >>> api_name: product_reviews
# >>> api_description: Get all product reviews. Infinite pagination/scrolling is supported using the *limit* and *offset* parameters.
# >>> param_properties:
# property_name: product_id | description: Product id of the product for which to fetch reviews. | type: STRING | default_value: None
# property_name: country | description: Country code of the region/country.
# Valid values: see https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2
# Default: `us`. | type: STRING | default_value: None
# property_name: language | description: The language of the results.
# Valid values: see https://en.wikipedia.org/wiki/List_of_ISO_639-1_codes
# Default: `en`. | type: STRING | default_value: None
# property_name: offset | description: Number of reviews to skip.
# Valid values: integers from 0-30000
# Default: `0`. | type: STRING | default_value: None
# ...
